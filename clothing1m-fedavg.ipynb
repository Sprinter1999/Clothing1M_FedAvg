# %%
import os
import copy
import numpy as np
import random
import torch
import torch.nn.functional as F
from torch.utils.data import Subset
import torch.nn as nn
from torchvision import datasets, transforms
from PIL import Image
from model_resnet_official import ResNet50
import torchvision.models as models
import time
import torchvision
from torch.cuda.amp import autocast as autocast

# %%
# torch settings
seed = 1
torch.manual_seed(1)
torch.cuda.manual_seed(1)
torch.cuda.manual_seed_all(1)
np.random.seed(1)
random.seed(1)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = True

# TODO:Hyperparameters Setting
# Main function
rootpath = "./record/"
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
datasetType = 'clothing1m'
num_classes = 14
model_name = 'resnet50'
num_users = 100
total_rounds = 40

# TODO:Load Data
# TODO: Load da

# %%
class Clothing(torch.utils.data.Dataset):
    def __init__(self, root, transform, mode):
        self.root = root
        self.noisy_labels = {}
        self.clean_labels = {}
        self.data = []
        self.targets = []
        self.transform = transform
        self.mode = mode

        with open(self.root + 'noisy_label_kv.txt', 'r') as f:
            lines = f.read().splitlines()
        for l in lines:
            entry = l.split()
            img_path = self.root + entry[0]
            self.noisy_labels[img_path] = int(entry[1])

        with open(self.root + 'clean_label_kv.txt', 'r') as f:
            lines = f.read().splitlines()
        for l in lines:
            entry = l.split()
            img_path = self.root + entry[0]
            self.clean_labels[img_path] = int(entry[1])

        if self.mode == 'train':
            with open(self.root + 'noisy_train_key_list.txt', 'r') as f:
                lines = f.read().splitlines()
            for l in lines:
                img_path = self.root + l
                self.data.append(img_path)
                target = self.noisy_labels[img_path]
                self.targets.append(target)
        elif self.mode == 'minitrain':
            with open(self.root + 'noisy_train_key_list.txt', 'r') as f:
                lines = f.read().splitlines()
            n = len(lines)
            np.random.seed(13)
            subset_idx = np.random.choice(n, int(n/10), replace=False)
            for i in subset_idx:
                l = lines[i]
                img_path = self.root + l
                self.data.append(img_path)
                target = self.noisy_labels[img_path]
                self.targets.append(target)
        elif self.mode == 'test':
            with open(self.root + 'clean_test_key_list.txt', 'r') as f:
                lines = f.read().splitlines()
            for l in lines:
                img_path = self.root + l
                self.data.append(img_path)
                target = self.clean_labels[img_path]
                self.targets.append(target)

    def __getitem__(self, index):
        img_path = self.data[index]
        target = self.targets[index]
        image = Image.open(img_path).convert('RGB')
        img = self.transform(image)
        return img, target

    def __len__(self):
        return len(self.data)


def iid_sampling(n_train, num_users, seed):
    np.random.seed(seed)
    num_items = int(n_train/num_users)
    # initial user and index for whole dataset
    ddict_users, all_idxs = {}, [i for i in range(n_train)]
    for i in range(num_users):
        # 'replace=False' make sure that there is no repeat
        ddict_users[i] = set(np.random.choice(
            all_idxs, num_items, replace=False))
        all_idxs = list(set(all_idxs)-ddict_users[i])
    return ddict_users


def get_dataset(datasetType):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    #TODO: remember to put your dataset in this directory
    if datasetType == 'clothing1m':
        data_path = './data/clothing1M/'
        trans_train = transforms.Compose([
            transforms.Resize((224, 224)),
#             transforms.RandomCrop(224),
#             transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[
                                 0.229, 0.224, 0.225]),
        ])
        trans_val = transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[
                                 0.229, 0.224, 0.225]),
        ])
        dataset_train = Clothing(data_path, trans_train, "train")
        dataset_test = Clothing(data_path, trans_val, "test")
        n_train = len(dataset_train)
        y_train = np.array(dataset_train.targets)
    else:
        exit('Error: unrecognized dataset')

    dict_users = iid_sampling(n_train, num_users, seed)

    return dataset_train, dataset_test, dict_users

# %%
def build_model():
    # choose different Neural network model for different args or input
    netglob = ResNet50(pretrained=False)
    # if args.pretrained:
    model = models.resnet50(pretrained=True)
    netglob.load_state_dict(model.state_dict())
    netglob.fc = nn.Linear(2048, num_classes)
    netglob = netglob.to(device)

    return netglob

#w_glob_fl = FedAvg(w_locals, dict_len)


def Averaging(w, dict_len):
    w_avg = copy.deepcopy(w[0])
    for k in w_avg.keys():
        w_avg[k] = w_avg[k] * dict_len[0]
        for i in range(1, len(w)):
            w_avg[k] += w[i][k] * dict_len[i]
        w_avg[k] = w_avg[k] / sum(dict_len)
    return w_avg


s=1
color_jitter = torchvision.transforms.ColorJitter(0.8 * s, 0.8 * s, 0.8 * s, 0.2 * s)

tt_transform = transforms.Compose([
#         transforms.RandomCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.RandomApply([color_jitter], p=0.8),
#         transforms.RandomApply([transforms.ColorJitter(0.4, 0.4, 0.4, 0.1)], p=0.8),
        transforms.RandomGrayscale(p=0.2)])


class LocalUpdate(object):
    def __init__(self, dataset, learning_rate, data_idxs):
        # self.client_index = client_index
        self.data_idxs = data_idxs
        self.batchsize = 64
        dataset_client = Subset(dataset, data_idxs) #modify
        self.train_loader = torch.utils.data.DataLoader(
            dataset=dataset_client, batch_size=self.batchsize, shuffle=True,drop_last=True,num_workers=4,pin_memory=True)
        self.learning_rate = learning_rate
        self.momentum = 0.9
        self.epochs = 5
        self.weight_decay = 0.0005
        self.local_datasize = len(data_idxs)
    
    def L1loss(self,predict,target):
        loss_f = nn.L1Loss(reduction='mean')
        l1_loss = loss_f(predict,target)
        return l1_loss
    
    def L2loss(self,predict,target):
        loss_f_mse = nn.MSELoss(reduction='mean')
        loss_mse = loss_f_mse(predict,target)
        return loss_mse

    def js(self, p_output, q_output):
        """
        Function that measures JS divergence between target and output logits:
        """
        KLDivLoss = nn.KLDivLoss(reduction='batchmean')
        log_mean_output = ((p_output + q_output )/2).log()
        return (KLDivLoss(log_mean_output, p_output) + KLDivLoss(log_mean_output, q_output))/2
    
    def train(self, model, current):
        criterion = nn.CrossEntropyLoss()
        e_loss = []
        model.cuda()
        for _ in range(1, self.epochs+1):  # _ means epoch
            train_loss = 0.0
            model.train()
            for data, labels in self.train_loader:
                if torch.cuda.is_available():
                    data, labels = data.cuda(non_blocking=True), labels.cuda(non_blocking=True)
#                     data_aug = tt_transform(data).cuda(non_blocking=True)   
                    
                optimizer = torch.optim.SGD(model.parameters(
                    ), lr=self.learning_rate, momentum=self.momentum, weight_decay=self.weight_decay)
                optimizer.zero_grad()  # clear the gradients
                
                mix_1 = np.random.beta(1,1)
                mix_2 = 1-mix_1
                
                # herein we exploit the mixed precision training technique to accelerate the FL process
                with autocast():
                    output = model(data)  # make a forward pass

                    loss = criterion(output, labels)   # calculate the loss
                
                loss.backward()  # do a backwards pass
                optimizer.step()  # perform a single optimization step
                train_loss += loss.item()*data.size(0)  # update training loss

            # average losses
            train_loss = train_loss/len(self.train_loader.dataset)
            print(f"Train for this client epoch {_} , loss {train_loss}")
            e_loss.append(train_loss)

        total_loss = sum(e_loss)/len(e_loss)
        return model.state_dict(), total_loss

# %%
print(device)
dataset_train, dataset_test, dict_users = get_dataset('clothing1m')
# build model
netglob = build_model()
net_local = build_model()
netglob = netglob.cuda()
net_local = net_local.cuda()
# Out:
# cuda:0

# %%
test_loader = torch.utils.data.DataLoader(
        dataset=dataset_test, batch_size=256, shuffle=False,num_workers=4,pin_memory=True)

def globaltest(net):
    print("Start Testing")
    net.cuda()
    net.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in test_loader:
            images, labels = images.cuda(non_blocking=True), labels.cuda(non_blocking=True)
            outputs = net(images)
            # outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    acc = correct / total
    print(f"acc {acc}")
    return acc

# %%
# client participation rate
C = 0.05

Clients = []
for idx in range(num_users):
    sample_idx = np.array(list(dict_users[idx]))
    cl = LocalUpdate(dataset=dataset_train,learning_rate=0.01, data_idxs=sample_idx)
    Clients.append(cl)
    print(f"Generate client {idx}")
    
    
    
print("Initialize Done")
f_acc = open(datasetType + '_fedavg_acc.txt', 'a')
acc_list = []
for _ in range(total_rounds):
    idxs_users = np.random.choice(num_users, int(num_users*C),replace=False)
    print(f"Round {_} selects {idxs_users}")
    
    # selected clients' model weights of each rounds
    w_locals = []
    
    
    # local training for each selected client
    for idx in idxs_users:
        net_local.load_state_dict(netglob.state_dict())
        local = Clients[idx]
        w, loss = local.train(model=copy.deepcopy(net_local).to(device),current=_)
        w_locals.append(copy.deepcopy(w))

    dict_len = [len(dict_users[idx]) for idx in idxs_users]
    print(f"start aggregation for round {_}")
    w_glob = Averaging(w_locals, dict_len)

    netglob.load_state_dict(copy.deepcopy(w_glob))
    acc_t = globaltest(copy.deepcopy(netglob).to(device))
    acc_list.append(acc_t)
    print(acc_list)
    f_acc.write("global round %d ,acc: %.4f \n" % (_, acc_t))
    # namep = str(_)+'_fedavg_round.pt'
    # torch.save(netglob.state_dict(),namep)
# Out:
# Generate client 0
# Generate client 1
# Generate client 2
# Generate client 3
# Generate client 4
# Generate client 5
# Generate client 6
# Generate client 7
# Generate client 8
# Generate client 9
# Generate client 10
# Generate client 11
# Generate client 12
# Generate client 13
# Generate client 14
# Generate client 15
# Generate client 16
# Generate client 17
# Generate client 18
# Generate client 19
# Generate client 20
# Generate client 21
# Generate client 22
# Generate client 23
# Generate client 24
# Generate client 25
# Generate client 26
# Generate client 27
# Generate client 28
# Generate client 29
# Generate client 30
# Generate client 31
# Generate client 32
# Generate client 33
# Generate client 34
# Generate client 35
# Generate client 36
# Generate client 37
# Generate client 38
# Generate client 39
# Generate client 40
# Generate client 41
# Generate client 42
# Generate client 43
# Generate client 44
# Generate client 45
# Generate client 46
# Generate client 47
# Generate client 48
# Generate client 49
# Generate client 50
# Generate client 51
# Generate client 52
# Generate client 53
# Generate client 54
# Generate client 55
# Generate client 56
# Generate client 57
# Generate client 58
# Generate client 59
# Generate client 60
# Generate client 61
# Generate client 62
# Generate client 63
# Generate client 64
# Generate client 65
# Generate client 66
# Generate client 67
# Generate client 68
# Generate client 69
# Generate client 70
# Generate client 71
# Generate client 72
# Generate client 73
# Generate client 74
# Generate client 75
# Generate client 76
# Generate client 77
# Generate client 78
# Generate client 79
# Generate client 80
# Generate client 81
# Generate client 82
# Generate client 83
# Generate client 84
# Generate client 85
# Generate client 86
# Generate client 87
# Generate client 88
# Generate client 89
# Generate client 90
# Generate client 91
# Generate client 92
# Generate client 93
# Generate client 94
# Generate client 95
# Generate client 96
# Generate client 97
# Generate client 98
# Generate client 99
# Initialize Done
# Round 0 selects [57 16 79 15 12]
# Train for this client epoch 1 , loss 1.8715790481567383
# Train for this client epoch 2 , loss 1.1620679042816162
# Train for this client epoch 3 , loss 0.847570329284668
# Train for this client epoch 4 , loss 0.591637190246582
# Train for this client epoch 5 , loss 0.3721729758262634
# Train for this client epoch 1 , loss 1.8454186363220215
# Train for this client epoch 2 , loss 1.1466509864807128
# Train for this client epoch 3 , loss 0.8298690315246582
# Train for this client epoch 4 , loss 0.5826984542846679
# Train for this client epoch 5 , loss 0.36466226978302
# Train for this client epoch 1 , loss 1.8528534240722656
# Train for this client epoch 2 , loss 1.1420545211791993
# Train for this client epoch 3 , loss 0.824420170211792
# Train for this client epoch 4 , loss 0.5738928533554077
# Train for this client epoch 5 , loss 0.3650560432434082
# Train for this client epoch 1 , loss 1.8714636711120605
# Train for this client epoch 2 , loss 1.143853734588623
# Train for this client epoch 3 , loss 0.8321630191802979
# Train for this client epoch 4 , loss 0.575878724861145
# Train for this client epoch 5 , loss 0.3538955887794495
# Train for this client epoch 1 , loss 1.861843839263916
# Train for this client epoch 2 , loss 1.1488216579437256
# Train for this client epoch 3 , loss 0.8412867916107177
# Train for this client epoch 4 , loss 0.5913156677246094
# Train for this client epoch 5 , loss 0.375852095413208
# start aggregation for round 0
# Start Testing
# acc 0.6312939388181645
# [0.6312939388181645]
# Round 1 selects [92 75 93 31 67]
# Train for this client epoch 1 , loss 0.9854314529418945
# Train for this client epoch 2 , loss 0.5700632432937622
# Train for this client epoch 3 , loss 0.31163522119522097
# Train for this client epoch 4 , loss 0.15702074966430665
# Train for this client epoch 5 , loss 0.0825495001912117
# Train for this client epoch 1 , loss 0.9624883670806885
# Train for this client epoch 2 , loss 0.5505918092727661
# Train for this client epoch 3 , loss 0.30179216690063476
# Train for this client epoch 4 , loss 0.15008253202438354
# Train for this client epoch 5 , loss 0.08047850416898727
# Train for this client epoch 1 , loss 0.9886664066314698
# Train for this client epoch 2 , loss 0.5696490768432617
# Train for this client epoch 3 , loss 0.3263089568138123
# Train for this client epoch 4 , loss 0.164133416557312
# Train for this client epoch 5 , loss 0.08677133550643922
# Train for this client epoch 1 , loss 0.988725997543335
# Train for this client epoch 2 , loss 0.5585517498016357
# Train for this client epoch 3 , loss 0.3099063690185547
# Train for this client epoch 4 , loss 0.154867125415802
# Train for this client epoch 5 , loss 0.07612264274358749
# Train for this client epoch 1 , loss 0.9787696773529053
# Train for this client epoch 2 , loss 0.5707117946624756
# Train for this client epoch 3 , loss 0.3116826325416565
# Train for this client epoch 4 , loss 0.16070477402210234
# Train for this client epoch 5 , loss 0.08594794763326645
# start aggregation for round 1
# Start Testing
# acc 0.6593197795933878
# [0.6312939388181645, 0.6593197795933878]
# Round 2 selects [43 35 94 25 96]
# Train for this client epoch 1 , loss 0.9723532741546631
# Train for this client epoch 2 , loss 0.4351157503128052
# Train for this client epoch 3 , loss 0.19295796723365782
# Train for this client epoch 4 , loss 0.07944143953323364
# Train for this client epoch 5 , loss 0.041248645412921905
# Train for this client epoch 1 , loss 0.9803537399291992
# Train for this client epoch 2 , loss 0.45455051116943357
# Train for this client epoch 3 , loss 0.20750199847221373
# Train for this client epoch 4 , loss 0.0869505769252777
# Train for this client epoch 5 , loss 0.04206975234746933
# Train for this client epoch 1 , loss 0.9566716995239258
# Train for this client epoch 2 , loss 0.43543477659225466
# Train for this client epoch 3 , loss 0.1898418879032135
# Train for this client epoch 4 , loss 0.08295660939216613
# Train for this client epoch 5 , loss 0.039586843430995944
# Train for this client epoch 1 , loss 0.9668554336547851
# Train for this client epoch 2 , loss 0.4336447429656982
# Train for this client epoch 3 , loss 0.1867991687297821
# Train for this client epoch 4 , loss 0.08156892253160476
# Train for this client epoch 5 , loss 0.03996373550891876
# Train for this client epoch 1 , loss 0.9456874574661255
# Train for this client epoch 2 , loss 0.43071140575408934
# Train for this client epoch 3 , loss 0.1916424517631531
# Train for this client epoch 4 , loss 0.07950178695917129
# Train for this client epoch 5 , loss 0.04029746675491333
# start aggregation for round 2
# Start Testing
# acc 0.6708151244537336
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336]
# Round 3 selects [66 92 63 68 32]
# Train for this client epoch 1 , loss 0.9314922430038453
# Train for this client epoch 2 , loss 0.3505341732025147
# Train for this client epoch 3 , loss 0.1321850119829178
# Train for this client epoch 4 , loss 0.05361964422464371
# Train for this client epoch 5 , loss 0.027156373941898345
# Train for this client epoch 1 , loss 0.7648702825546264
# Train for this client epoch 2 , loss 0.24089500851631165
# Train for this client epoch 3 , loss 0.0793859901547432
# Train for this client epoch 4 , loss 0.03172079719305038
# Train for this client epoch 5 , loss 0.019454623794555665
# Train for this client epoch 1 , loss 0.9164122608184815
# Train for this client epoch 2 , loss 0.37371246776580813
# Train for this client epoch 3 , loss 0.14033474481105804
# Train for this client epoch 4 , loss 0.05692165652513504
# Train for this client epoch 5 , loss 0.02808506691455841
# Train for this client epoch 1 , loss 0.9501729835510254
# Train for this client epoch 2 , loss 0.3873916293144226
# Train for this client epoch 3 , loss 0.15438302822113037
# Train for this client epoch 4 , loss 0.058796106564998625
# Train for this client epoch 5 , loss 0.02920050460100174
# Train for this client epoch 1 , loss 0.9241134777069092
# Train for this client epoch 2 , loss 0.3688100751876831
# Train for this client epoch 3 , loss 0.13998909313678742
# Train for this client epoch 4 , loss 0.05438500291109085
# Train for this client epoch 5 , loss 0.02699265123605728
# start aggregation for round 3
# Start Testing
# acc 0.6770853125593768
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768]
# Round 4 selects [ 7 79 85 11 41]
# Train for this client epoch 1 , loss 0.9232675355911255
# Train for this client epoch 2 , loss 0.34209759035110476
# Train for this client epoch 3 , loss 0.11660991399288177
# Train for this client epoch 4 , loss 0.044872212529182436
# Train for this client epoch 5 , loss 0.021467603945732116
# Train for this client epoch 1 , loss 0.8011318998336792
# Train for this client epoch 2 , loss 0.2724859923362732
# Train for this client epoch 3 , loss 0.08966201884746551
# Train for this client epoch 4 , loss 0.032878053402900696
# Train for this client epoch 5 , loss 0.01709850573539734
# Train for this client epoch 1 , loss 0.9094885746002197
# Train for this client epoch 2 , loss 0.3448792847633362
# Train for this client epoch 3 , loss 0.12131425631046296
# Train for this client epoch 4 , loss 0.043293431055545804
# Train for this client epoch 5 , loss 0.020271483278274535
# Train for this client epoch 1 , loss 0.8942348360061646
# Train for this client epoch 2 , loss 0.3326153004646301
# Train for this client epoch 3 , loss 0.11560773618221283
# Train for this client epoch 4 , loss 0.04268420913219452
# Train for this client epoch 5 , loss 0.023170107674598695
# Train for this client epoch 1 , loss 0.9173938671112061
# Train for this client epoch 2 , loss 0.34191270899772647
# Train for this client epoch 3 , loss 0.11482328841686248
# Train for this client epoch 4 , loss 0.04380135010480881
# Train for this client epoch 5 , loss 0.020973690044879912
# start aggregation for round 4
# Start Testing
# acc 0.6798403952118564
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564]
# Round 5 selects [59 88 16 86 97]
# Train for this client epoch 1 , loss 0.9024075294494629
# Train for this client epoch 2 , loss 0.3205654296875
# Train for this client epoch 3 , loss 0.10618811137676239
# Train for this client epoch 4 , loss 0.03747413508892059
# Train for this client epoch 5 , loss 0.017824198591709136
# Train for this client epoch 1 , loss 0.8892167236328125
# Train for this client epoch 2 , loss 0.31267535104751587
# Train for this client epoch 3 , loss 0.10174466593265534
# Train for this client epoch 4 , loss 0.03579163553714752
# Train for this client epoch 5 , loss 0.018671698009967805
# Train for this client epoch 1 , loss 0.7864921520233155
# Train for this client epoch 2 , loss 0.23819809155464172
# Train for this client epoch 3 , loss 0.07515943452119828
# Train for this client epoch 4 , loss 0.027573523211479187
# Train for this client epoch 5 , loss 0.016791050577163697
# Train for this client epoch 1 , loss 0.8946582260131836
# Train for this client epoch 2 , loss 0.3123152932167053
# Train for this client epoch 3 , loss 0.10116818095445633
# Train for this client epoch 4 , loss 0.0344612811088562
# Train for this client epoch 5 , loss 0.017044583439826965
# Train for this client epoch 1 , loss 0.9084099271774292
# Train for this client epoch 2 , loss 0.33754450569152833
# Train for this client epoch 3 , loss 0.1118160553574562
# Train for this client epoch 4 , loss 0.0366735857963562
# Train for this client epoch 5 , loss 0.018182224237918855
# start aggregation for round 5
# Start Testing
# acc 0.6861105833174995
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564, 0.6861105833174995]
# Round 6 selects [62 82 71 79 32]
# Train for this client epoch 1 , loss 0.8569600997924804
# Train for this client epoch 2 , loss 0.29690607771873473
# Train for this client epoch 3 , loss 0.0884937890291214
# Train for this client epoch 4 , loss 0.03085617115497589
# Train for this client epoch 5 , loss 0.016275357222557067
# Train for this client epoch 1 , loss 0.8587887048721313
# Train for this client epoch 2 , loss 0.2976171096801758
# Train for this client epoch 3 , loss 0.08911814351081848
# Train for this client epoch 4 , loss 0.027920102858543395
# Train for this client epoch 5 , loss 0.01466328226327896
# Train for this client epoch 1 , loss 0.845379222869873
# Train for this client epoch 2 , loss 0.296900186920166
# Train for this client epoch 3 , loss 0.08308125611543656
# Train for this client epoch 4 , loss 0.02888100692033768
# Train for this client epoch 5 , loss 0.01544719364643097
# Train for this client epoch 1 , loss 0.591426159286499
# Train for this client epoch 2 , loss 0.14287528421878815
# Train for this client epoch 3 , loss 0.034214883685111996
# Train for this client epoch 4 , loss 0.014411506760120391
# Train for this client epoch 5 , loss 0.010880847418308259
# Train for this client epoch 1 , loss 0.6934040246963501
# Train for this client epoch 2 , loss 0.16863521099090575
# Train for this client epoch 3 , loss 0.04411943455934524
# Train for this client epoch 4 , loss 0.0174384853720665
# Train for this client epoch 5 , loss 0.010973404157161713
# start aggregation for round 6
# Start Testing
# acc 0.685445563366901
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564, 0.6861105833174995, 0.685445563366901]
# Round 7 selects [61  6 77 71 14]
# Train for this client epoch 1 , loss 0.8389134256362915
# Train for this client epoch 2 , loss 0.2734881203174591
# Train for this client epoch 3 , loss 0.07824141392707824
# Train for this client epoch 4 , loss 0.026176674842834473
# Train for this client epoch 5 , loss 0.013570461213588715
# Train for this client epoch 1 , loss 0.8445144851684571
# Train for this client epoch 2 , loss 0.2767796821117401
# Train for this client epoch 3 , loss 0.07793020025491715
# Train for this client epoch 4 , loss 0.026859520387649535
# Train for this client epoch 5 , loss 0.013152507841587066
# Train for this client epoch 1 , loss 0.8354000993728637
# Train for this client epoch 2 , loss 0.2763766263008118
# Train for this client epoch 3 , loss 0.08338229968547821
# Train for this client epoch 4 , loss 0.026205142211914063
# Train for this client epoch 5 , loss 0.01543538602590561
# Train for this client epoch 1 , loss 0.610988032913208
# Train for this client epoch 2 , loss 0.13547615051269532
# Train for this client epoch 3 , loss 0.033383711791038516
# Train for this client epoch 4 , loss 0.01504196503162384
# Train for this client epoch 5 , loss 0.009263516652584076
# Train for this client epoch 1 , loss 0.8378672410964966
# Train for this client epoch 2 , loss 0.2712225263595581
# Train for this client epoch 3 , loss 0.08372343133687973
# Train for this client epoch 4 , loss 0.030683143424987794
# Train for this client epoch 5 , loss 0.015298681712150574
# start aggregation for round 7
# Start Testing
# acc 0.687345620368611
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564, 0.6861105833174995, 0.685445563366901, 0.687345620368611]
# Round 8 selects [ 3 61 22 65 46]
# Train for this client epoch 1 , loss 0.8254607482910157
# Train for this client epoch 2 , loss 0.267925409078598
# Train for this client epoch 3 , loss 0.07547011386156083
# Train for this client epoch 4 , loss 0.023600526916980745
# Train for this client epoch 5 , loss 0.012116921877861023
# Train for this client epoch 1 , loss 0.6112720743179322
# Train for this client epoch 2 , loss 0.13170965054035186
# Train for this client epoch 3 , loss 0.03430676681995392
# Train for this client epoch 4 , loss 0.012810959434509278
# Train for this client epoch 5 , loss 0.008658111500740051
# Train for this client epoch 1 , loss 0.796655214881897
# Train for this client epoch 2 , loss 0.2597813935756683
# Train for this client epoch 3 , loss 0.07220371716022492
# Train for this client epoch 4 , loss 0.021696083319187164
# Train for this client epoch 5 , loss 0.011394460904598237
# Train for this client epoch 1 , loss 0.7917155349731445
# Train for this client epoch 2 , loss 0.2567778076171875
# Train for this client epoch 3 , loss 0.07113295273780823
# Train for this client epoch 4 , loss 0.022660834288597106
# Train for this client epoch 5 , loss 0.012202637267112732
# Train for this client epoch 1 , loss 0.820987731552124
# Train for this client epoch 2 , loss 0.27738302936553955
# Train for this client epoch 3 , loss 0.07292229758501052
# Train for this client epoch 4 , loss 0.02254801768064499
# Train for this client epoch 5 , loss 0.012106231153011323
# start aggregation for round 8
# Start Testing
# acc 0.6891506745202356
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564, 0.6861105833174995, 0.685445563366901, 0.687345620368611, 0.6891506745202356]
# Round 9 selects [15 94 76 38 50]
# Train for this client epoch 1 , loss 0.744218712425232
# Train for this client epoch 2 , loss 0.22226694288253784
# Train for this client epoch 3 , loss 0.05335755394697189
# Train for this client epoch 4 , loss 0.01836830104589462
# Train for this client epoch 5 , loss 0.010004725992679596
# Train for this client epoch 1 , loss 0.7049838401794434
# Train for this client epoch 2 , loss 0.1762923167705536
# Train for this client epoch 3 , loss 0.04061212828159332
# Train for this client epoch 4 , loss 0.015165583884716035
# Train for this client epoch 5 , loss 0.008604607903957368
# Train for this client epoch 1 , loss 0.7854586584091187
# Train for this client epoch 2 , loss 0.25656712169647217
# Train for this client epoch 3 , loss 0.06341305627822875
# Train for this client epoch 4 , loss 0.020187690997123718
# Train for this client epoch 5 , loss 0.009513217127323151
# Train for this client epoch 1 , loss 0.7987479215621949
# Train for this client epoch 2 , loss 0.2573480100154877
# Train for this client epoch 3 , loss 0.06454214717149734
# Train for this client epoch 4 , loss 0.02122007896900177
# Train for this client epoch 5 , loss 0.011330436384677888
# Train for this client epoch 1 , loss 0.8147024692535401
# Train for this client epoch 2 , loss 0.26063040375709534
# Train for this client epoch 3 , loss 0.06911630375385285
# Train for this client epoch 4 , loss 0.022163719928264616
# Train for this client epoch 5 , loss 0.012246273934841156
# start aggregation for round 9
# Start Testing
# acc 0.6871556146684401
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564, 0.6861105833174995, 0.685445563366901, 0.687345620368611, 0.6891506745202356, 0.6871556146684401]
# Round 10 selects [ 9 30 17 46 15]
# Train for this client epoch 1 , loss 0.7659161922454834
# Train for this client epoch 2 , loss 0.24687436985969544
# Train for this client epoch 3 , loss 0.060493611562252046
# Train for this client epoch 4 , loss 0.018280554687976836
# Train for this client epoch 5 , loss 0.009691576063632966
# Train for this client epoch 1 , loss 0.752910788154602
# Train for this client epoch 2 , loss 0.23216738810539245
# Train for this client epoch 3 , loss 0.05620800393819809
# Train for this client epoch 4 , loss 0.01858881254196167
# Train for this client epoch 5 , loss 0.010539549160003662
# Train for this client epoch 1 , loss 0.7936874319076538
# Train for this client epoch 2 , loss 0.2689934498786926
# Train for this client epoch 3 , loss 0.06627452713251114
# Train for this client epoch 4 , loss 0.020367721581459046
# Train for this client epoch 5 , loss 0.010343871760368347
# Train for this client epoch 1 , loss 0.6089854719161988
# Train for this client epoch 2 , loss 0.1302708665370941
# Train for this client epoch 3 , loss 0.02713553295135498
# Train for this client epoch 4 , loss 0.012357232892513274
# Train for this client epoch 5 , loss 0.0077549145579338076
# Train for this client epoch 1 , loss 0.5100303900718689
# Train for this client epoch 2 , loss 0.10237371168136597
# Train for this client epoch 3 , loss 0.025499830448627473
# Train for this client epoch 4 , loss 0.011961568200588227
# Train for this client epoch 5 , loss 0.007558531391620636
# start aggregation for round 10
# Start Testing
# acc 0.686205586167585
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564, 0.6861105833174995, 0.685445563366901, 0.687345620368611, 0.6891506745202356, 0.6871556146684401, 0.686205586167585]
# Round 11 selects [95 20 63 41 78]
# Train for this client epoch 1 , loss 0.7469273187637329
# Train for this client epoch 2 , loss 0.23344533863067626
# Train for this client epoch 3 , loss 0.05940436773300171
# Train for this client epoch 4 , loss 0.017113775730133056
# Train for this client epoch 5 , loss 0.009581552863121033
# Train for this client epoch 1 , loss 0.7415492679595947
# Train for this client epoch 2 , loss 0.2416657564640045
# Train for this client epoch 3 , loss 0.06388010902404785
# Train for this client epoch 4 , loss 0.01872340101003647
# Train for this client epoch 5 , loss 0.009468375420570373
# Train for this client epoch 1 , loss 0.6435132610321045
# Train for this client epoch 2 , loss 0.1539123041152954
# Train for this client epoch 3 , loss 0.03301578396558762
# Train for this client epoch 4 , loss 0.012176065802574158
# Train for this client epoch 5 , loss 0.008024890637397766
# Train for this client epoch 1 , loss 0.6584133752822876
# Train for this client epoch 2 , loss 0.15242318861484527
# Train for this client epoch 3 , loss 0.036625564193725584
# Train for this client epoch 4 , loss 0.013232353377342224
# Train for this client epoch 5 , loss 0.008068832004070282
# Train for this client epoch 1 , loss 0.7547758140563965
# Train for this client epoch 2 , loss 0.24812429785728454
# Train for this client epoch 3 , loss 0.05817673449516297
# Train for this client epoch 4 , loss 0.01992543978691101
# Train for this client epoch 5 , loss 0.010257503926753998
# start aggregation for round 11
# Start Testing
# acc 0.6884856545696371
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564, 0.6861105833174995, 0.685445563366901, 0.687345620368611, 0.6891506745202356, 0.6871556146684401, 0.686205586167585, 0.6884856545696371]
# Round 12 selects [78 11 87 83 28]
# Train for this client epoch 1 , loss 0.5390717728614807
# Train for this client epoch 2 , loss 0.1096946293234825
# Train for this client epoch 3 , loss 0.023624720871448516
# Train for this client epoch 4 , loss 0.009538427472114563
# Train for this client epoch 5 , loss 0.006694562935829163
# Train for this client epoch 1 , loss 0.6225232389450073
# Train for this client epoch 2 , loss 0.15561068890094756
# Train for this client epoch 3 , loss 0.03216521170139313
# Train for this client epoch 4 , loss 0.011664015209674835
# Train for this client epoch 5 , loss 0.007383120715618133
# Train for this client epoch 1 , loss 0.7529019622802734
# Train for this client epoch 2 , loss 0.2520885993003845
# Train for this client epoch 3 , loss 0.05919434951543808
# Train for this client epoch 4 , loss 0.018680599129199983
# Train for this client epoch 5 , loss 0.008912811267375946
# Train for this client epoch 1 , loss 0.7353240665435791
# Train for this client epoch 2 , loss 0.23400538563728332
# Train for this client epoch 3 , loss 0.05526989201307297
# Train for this client epoch 4 , loss 0.016085815358161927
# Train for this client epoch 5 , loss 0.009118197953701019
# Train for this client epoch 1 , loss 0.7331194120407104
# Train for this client epoch 2 , loss 0.23318437376022338
# Train for this client epoch 3 , loss 0.055586883187294
# Train for this client epoch 4 , loss 0.015971842062473297
# Train for this client epoch 5 , loss 0.008600080406665801
# start aggregation for round 12
# Start Testing
# acc 0.6893406802204066
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564, 0.6861105833174995, 0.685445563366901, 0.687345620368611, 0.6891506745202356, 0.6871556146684401, 0.686205586167585, 0.6884856545696371, 0.6893406802204066]
# Round 13 selects [83  1 88 51 22]
# Train for this client epoch 1 , loss 0.520633246421814
# Train for this client epoch 2 , loss 0.09573483047485351
# Train for this client epoch 3 , loss 0.02276890962123871
# Train for this client epoch 4 , loss 0.009980088484287261
# Train for this client epoch 5 , loss 0.005609994840621948
# Train for this client epoch 1 , loss 0.7198064785003662
# Train for this client epoch 2 , loss 0.22503504433631896
# Train for this client epoch 3 , loss 0.05150385655164719
# Train for this client epoch 4 , loss 0.014421087992191314
# Train for this client epoch 5 , loss 0.0071005805373191835
# Train for this client epoch 1 , loss 0.6326363519668579
# Train for this client epoch 2 , loss 0.1491150592327118
# Train for this client epoch 3 , loss 0.03334303644895554
# Train for this client epoch 4 , loss 0.012181060779094696
# Train for this client epoch 5 , loss 0.006594175374507904
# Train for this client epoch 1 , loss 0.7509234628677368
# Train for this client epoch 2 , loss 0.2548300027370453
# Train for this client epoch 3 , loss 0.05502304462194443
# Train for this client epoch 4 , loss 0.016755064487457276
# Train for this client epoch 5 , loss 0.008196251821517944
# Train for this client epoch 1 , loss 0.5923262762069702
# Train for this client epoch 2 , loss 0.13742220559120177
# Train for this client epoch 3 , loss 0.02639914675951004
# Train for this client epoch 4 , loss 0.010985920143127442
# Train for this client epoch 5 , loss 0.005776859736442566
# start aggregation for round 13
# Start Testing
# acc 0.6879156374691241
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564, 0.6861105833174995, 0.685445563366901, 0.687345620368611, 0.6891506745202356, 0.6871556146684401, 0.686205586167585, 0.6884856545696371, 0.6893406802204066, 0.6879156374691241]
# Round 14 selects [87 11 43 83 88]
# Train for this client epoch 1 , loss 0.5534493337631226
# Train for this client epoch 2 , loss 0.11044253393411636
# Train for this client epoch 3 , loss 0.027643970596790315
# Train for this client epoch 4 , loss 0.009789428508281708
# Train for this client epoch 5 , loss 0.006285104501247406
# Train for this client epoch 1 , loss 0.445700612449646
# Train for this client epoch 2 , loss 0.07607596111297607
# Train for this client epoch 3 , loss 0.01930574688911438
# Train for this client epoch 4 , loss 0.00791246544122696
# Train for this client epoch 5 , loss 0.005143846476078033
# Train for this client epoch 1 , loss 0.6603830059051514
# Train for this client epoch 2 , loss 0.16448600149154663
# Train for this client epoch 3 , loss 0.03633602430820465
# Train for this client epoch 4 , loss 0.012016641116142273
# Train for this client epoch 5 , loss 0.0070012207746505736
# Train for this client epoch 1 , loss 0.3372105628490448
# Train for this client epoch 2 , loss 0.0583670770406723
# Train for this client epoch 3 , loss 0.015353801941871643
# Train for this client epoch 4 , loss 0.006934377908706665
# Train for this client epoch 5 , loss 0.004821510767936707
# Train for this client epoch 1 , loss 0.43150802698135377
# Train for this client epoch 2 , loss 0.08159204263687134
# Train for this client epoch 3 , loss 0.0206982807636261
# Train for this client epoch 4 , loss 0.008565530562400819
# Train for this client epoch 5 , loss 0.0057612494468688965
# start aggregation for round 14
# Start Testing
# acc 0.6876306289188676
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564, 0.6861105833174995, 0.685445563366901, 0.687345620368611, 0.6891506745202356, 0.6871556146684401, 0.686205586167585, 0.6884856545696371, 0.6893406802204066, 0.6879156374691241, 0.6876306289188676]
# Round 15 selects [ 9 22 30 25 62]
# Train for this client epoch 1 , loss 0.5793888116836547
# Train for this client epoch 2 , loss 0.12106194492578506
# Train for this client epoch 3 , loss 0.02685888855457306
# Train for this client epoch 4 , loss 0.01208073161840439
# Train for this client epoch 5 , loss 0.005686091339588166
# Train for this client epoch 1 , loss 0.43267027311325074
# Train for this client epoch 2 , loss 0.07656789499521255
# Train for this client epoch 3 , loss 0.02024826102256775
# Train for this client epoch 4 , loss 0.006801326894760132
# Train for this client epoch 5 , loss 0.004838336956501007
# Train for this client epoch 1 , loss 0.5710845663070678
# Train for this client epoch 2 , loss 0.1194295338511467
# Train for this client epoch 3 , loss 0.026891291248798372
# Train for this client epoch 4 , loss 0.009784341669082642
# Train for this client epoch 5 , loss 0.00502289000749588
# Train for this client epoch 1 , loss 0.6612134872436524
# Train for this client epoch 2 , loss 0.16965726592540742
# Train for this client epoch 3 , loss 0.03540379257202148
# Train for this client epoch 4 , loss 0.012051637530326844
# Train for this client epoch 5 , loss 0.0063005657196044925
# Train for this client epoch 1 , loss 0.6213946699142456
# Train for this client epoch 2 , loss 0.1458957755923271
# Train for this client epoch 3 , loss 0.02875688455104828
# Train for this client epoch 4 , loss 0.010625679540634154
# Train for this client epoch 5 , loss 0.006069265139102936
# start aggregation for round 15
# Start Testing
# acc 0.6868706061181835
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564, 0.6861105833174995, 0.685445563366901, 0.687345620368611, 0.6891506745202356, 0.6871556146684401, 0.686205586167585, 0.6884856545696371, 0.6893406802204066, 0.6879156374691241, 0.6876306289188676, 0.6868706061181835]
# Round 16 selects [54 19 92 71 43]
# Train for this client epoch 1 , loss 0.7188997476577759
# Train for this client epoch 2 , loss 0.22022264537811279
# Train for this client epoch 3 , loss 0.049413275492191315
# Train for this client epoch 4 , loss 0.013382428872585297
# Train for this client epoch 5 , loss 0.0066902358651161195
# Train for this client epoch 1 , loss 0.7061095443725586
# Train for this client epoch 2 , loss 0.20081532843112945
# Train for this client epoch 3 , loss 0.03978596447706222
# Train for this client epoch 4 , loss 0.013838696217536927
# Train for this client epoch 5 , loss 0.006417729711532593
# Train for this client epoch 1 , loss 0.6060162233352662
# Train for this client epoch 2 , loss 0.12937137820720673
# Train for this client epoch 3 , loss 0.025813112461566926
# Train for this client epoch 4 , loss 0.011585719287395477
# Train for this client epoch 5 , loss 0.00570601954460144
# Train for this client epoch 1 , loss 0.5131555303573608
# Train for this client epoch 2 , loss 0.0795267904996872
# Train for this client epoch 3 , loss 0.018676428508758544
# Train for this client epoch 4 , loss 0.009025993382930756
# Train for this client epoch 5 , loss 0.005609861588478088
# Train for this client epoch 1 , loss 0.4804684549331665
# Train for this client epoch 2 , loss 0.08279866510629653
# Train for this client epoch 3 , loss 0.016936060857772828
# Train for this client epoch 4 , loss 0.007566008675098419
# Train for this client epoch 5 , loss 0.004415085232257843
# start aggregation for round 16
# Start Testing
# acc 0.6847805434163025
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564, 0.6861105833174995, 0.685445563366901, 0.687345620368611, 0.6891506745202356, 0.6871556146684401, 0.686205586167585, 0.6884856545696371, 0.6893406802204066, 0.6879156374691241, 0.6876306289188676, 0.6868706061181835, 0.6847805434163025]
# Round 17 selects [13 43  4 85 77]
# Train for this client epoch 1 , loss 0.6881255384445191
# Train for this client epoch 2 , loss 0.20830160460472108
# Train for this client epoch 3 , loss 0.04356193070411682
# Train for this client epoch 4 , loss 0.01325278675556183
# Train for this client epoch 5 , loss 0.00654659743309021
# Train for this client epoch 1 , loss 0.30014061427116395
# Train for this client epoch 2 , loss 0.05249222273826599
# Train for this client epoch 3 , loss 0.01383137571811676
# Train for this client epoch 4 , loss 0.005710806679725647
# Train for this client epoch 5 , loss 0.00376641309261322
# Train for this client epoch 1 , loss 0.6864363569259644
# Train for this client epoch 2 , loss 0.1927075442790985
# Train for this client epoch 3 , loss 0.03987015644311905
# Train for this client epoch 4 , loss 0.013821661269664765
# Train for this client epoch 5 , loss 0.007818431723117828
# Train for this client epoch 1 , loss 0.6228035764694214
# Train for this client epoch 2 , loss 0.14333668959140777
# Train for this client epoch 3 , loss 0.02969829932451248
# Train for this client epoch 4 , loss 0.011046917176246644
# Train for this client epoch 5 , loss 0.007337893664836883
# Train for this client epoch 1 , loss 0.6129401733398437
# Train for this client epoch 2 , loss 0.13420046608448027
# Train for this client epoch 3 , loss 0.027807254660129548
# Train for this client epoch 4 , loss 0.01166186032295227
# Train for this client epoch 5 , loss 0.005689658772945404
# start aggregation for round 17
# Start Testing
# acc 0.6883906517195516
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564, 0.6861105833174995, 0.685445563366901, 0.687345620368611, 0.6891506745202356, 0.6871556146684401, 0.686205586167585, 0.6884856545696371, 0.6893406802204066, 0.6879156374691241, 0.6876306289188676, 0.6868706061181835, 0.6847805434163025, 0.6883906517195516]
# Round 18 selects [92 30 36 29 18]
# Train for this client epoch 1 , loss 0.4293313995361328
# Train for this client epoch 2 , loss 0.06946614412069321
# Train for this client epoch 3 , loss 0.017078745114803316
# Train for this client epoch 4 , loss 0.007808796107769012
# Train for this client epoch 5 , loss 0.004361160266399384
# Train for this client epoch 1 , loss 0.42313350219726564
# Train for this client epoch 2 , loss 0.06735670137405396
# Train for this client epoch 3 , loss 0.016870445144176485
# Train for this client epoch 4 , loss 0.006603090023994446
# Train for this client epoch 5 , loss 0.0046484851479530334
# Train for this client epoch 1 , loss 0.6995668802261352
# Train for this client epoch 2 , loss 0.20914875264167784
# Train for this client epoch 3 , loss 0.04308252843618393
# Train for this client epoch 4 , loss 0.012915408504009247
# Train for this client epoch 5 , loss 0.006327069973945618
# Train for this client epoch 1 , loss 0.6988572612762451
# Train for this client epoch 2 , loss 0.20694676814079285
# Train for this client epoch 3 , loss 0.04550089944601059
# Train for this client epoch 4 , loss 0.013082804584503173
# Train for this client epoch 5 , loss 0.007154207515716553
# Train for this client epoch 1 , loss 0.6730115850448608
# Train for this client epoch 2 , loss 0.19596705753803254
# Train for this client epoch 3 , loss 0.0409511155128479
# Train for this client epoch 4 , loss 0.011970584440231323
# Train for this client epoch 5 , loss 0.006738459157943725
# start aggregation for round 18
# Start Testing
# acc 0.68525555766673
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564, 0.6861105833174995, 0.685445563366901, 0.687345620368611, 0.6891506745202356, 0.6871556146684401, 0.686205586167585, 0.6884856545696371, 0.6893406802204066, 0.6879156374691241, 0.6876306289188676, 0.6868706061181835, 0.6847805434163025, 0.6883906517195516, 0.68525555766673]
# Round 19 selects [86 65 90 47  8]
# Train for this client epoch 1 , loss 0.6188019612312317
# Train for this client epoch 2 , loss 0.1448697084903717
# Train for this client epoch 3 , loss 0.03327694182395935
# Train for this client epoch 4 , loss 0.012693162047863006
# Train for this client epoch 5 , loss 0.005081188154220581
# Train for this client epoch 1 , loss 0.5807181451797485
# Train for this client epoch 2 , loss 0.12799308726787567
# Train for this client epoch 3 , loss 0.026350895273685455
# Train for this client epoch 4 , loss 0.00808494609594345
# Train for this client epoch 5 , loss 0.005092215919494629
# Train for this client epoch 1 , loss 0.6916190391540528
# Train for this client epoch 2 , loss 0.20678021993637086
# Train for this client epoch 3 , loss 0.04672365783452988
# Train for this client epoch 4 , loss 0.012565660095214844
# Train for this client epoch 5 , loss 0.006604016780853272
# Train for this client epoch 1 , loss 0.6897082180023193
# Train for this client epoch 2 , loss 0.20782985558509826
# Train for this client epoch 3 , loss 0.03960441254377365
# Train for this client epoch 4 , loss 0.01338793169260025
# Train for this client epoch 5 , loss 0.006230181586742401
# Train for this client epoch 1 , loss 0.6944396938323975
# Train for this client epoch 2 , loss 0.20228400952816009
# Train for this client epoch 3 , loss 0.04320717440843582
# Train for this client epoch 4 , loss 0.01348350349664688
# Train for this client epoch 5 , loss 0.006882108891010284
# start aggregation for round 19
# Start Testing
# acc 0.687535626068782
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564, 0.6861105833174995, 0.685445563366901, 0.687345620368611, 0.6891506745202356, 0.6871556146684401, 0.686205586167585, 0.6884856545696371, 0.6893406802204066, 0.6879156374691241, 0.6876306289188676, 0.6868706061181835, 0.6847805434163025, 0.6883906517195516, 0.68525555766673, 0.687535626068782]
# Round 20 selects [20 68 28 29 48]
# Train for this client epoch 1 , loss 0.5641597381591796
# Train for this client epoch 2 , loss 0.11772918927669525
# Train for this client epoch 3 , loss 0.02635635493993759
# Train for this client epoch 4 , loss 0.009506178939342498
# Train for this client epoch 5 , loss 0.00529054616689682
# Train for this client epoch 1 , loss 0.6149110233306885
# Train for this client epoch 2 , loss 0.1589917823076248
# Train for this client epoch 3 , loss 0.02890701013803482
# Train for this client epoch 4 , loss 0.009906016087532044
# Train for this client epoch 5 , loss 0.005733865833282471
# Train for this client epoch 1 , loss 0.5652660945892334
# Train for this client epoch 2 , loss 0.10428882516622544
# Train for this client epoch 3 , loss 0.02309849783182144
# Train for this client epoch 4 , loss 0.009367328083515166
# Train for this client epoch 5 , loss 0.005063329601287842
# Train for this client epoch 1 , loss 0.5017038444519043
# Train for this client epoch 2 , loss 0.087729832136631
# Train for this client epoch 3 , loss 0.020579117155075072
# Train for this client epoch 4 , loss 0.007789511215686798
# Train for this client epoch 5 , loss 0.004212788462638855
# Train for this client epoch 1 , loss 0.6608515775680542
# Train for this client epoch 2 , loss 0.1928083437204361
# Train for this client epoch 3 , loss 0.04369623000621796
# Train for this client epoch 4 , loss 0.0121330175280571
# Train for this client epoch 5 , loss 0.005670586538314819
# start aggregation for round 20
# Start Testing
# acc 0.6853505605168155
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564, 0.6861105833174995, 0.685445563366901, 0.687345620368611, 0.6891506745202356, 0.6871556146684401, 0.686205586167585, 0.6884856545696371, 0.6893406802204066, 0.6879156374691241, 0.6876306289188676, 0.6868706061181835, 0.6847805434163025, 0.6883906517195516, 0.68525555766673, 0.687535626068782, 0.6853505605168155]
# Round 21 selects [97 26 85 79 31]
# Train for this client epoch 1 , loss 0.608704444694519
# Train for this client epoch 2 , loss 0.15197535307407378
# Train for this client epoch 3 , loss 0.02726311353445053
# Train for this client epoch 4 , loss 0.00997458336353302
# Train for this client epoch 5 , loss 0.006020116376876831
# Train for this client epoch 1 , loss 0.6771274108886719
# Train for this client epoch 2 , loss 0.19352704825401307
# Train for this client epoch 3 , loss 0.03813668922185898
# Train for this client epoch 4 , loss 0.010283576118946076
# Train for this client epoch 5 , loss 0.006180039381980896
# Train for this client epoch 1 , loss 0.4673153356552124
# Train for this client epoch 2 , loss 0.07376419607400894
# Train for this client epoch 3 , loss 0.01836097240447998
# Train for this client epoch 4 , loss 0.007832025170326233
# Train for this client epoch 5 , loss 0.004537874972820282
# Train for this client epoch 1 , loss 0.5118459029197693
# Train for this client epoch 2 , loss 0.08697053921222687
# Train for this client epoch 3 , loss 0.018293300473690034
# Train for this client epoch 4 , loss 0.006427305114269257
# Train for this client epoch 5 , loss 0.003643310534954071
# Train for this client epoch 1 , loss 0.6168309120178223
# Train for this client epoch 2 , loss 0.16473697588443756
# Train for this client epoch 3 , loss 0.03045886650085449
# Train for this client epoch 4 , loss 0.010594138872623443
# Train for this client epoch 5 , loss 0.005233034408092499
# start aggregation for round 21
# Start Testing
# acc 0.6904807144214327
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564, 0.6861105833174995, 0.685445563366901, 0.687345620368611, 0.6891506745202356, 0.6871556146684401, 0.686205586167585, 0.6884856545696371, 0.6893406802204066, 0.6879156374691241, 0.6876306289188676, 0.6868706061181835, 0.6847805434163025, 0.6883906517195516, 0.68525555766673, 0.687535626068782, 0.6853505605168155, 0.6904807144214327]
# Round 22 selects [66 75  0 27 55]
# Train for this client epoch 1 , loss 0.5870118469238281
# Train for this client epoch 2 , loss 0.1285348490834236
# Train for this client epoch 3 , loss 0.024887304091453552
# Train for this client epoch 4 , loss 0.00880301479101181
# Train for this client epoch 5 , loss 0.0054912748336791994
# Train for this client epoch 1 , loss 0.6113503234863281
# Train for this client epoch 2 , loss 0.15797111384868623
# Train for this client epoch 3 , loss 0.03658971985578537
# Train for this client epoch 4 , loss 0.009853821301460267
# Train for this client epoch 5 , loss 0.005977041292190552
# Train for this client epoch 1 , loss 0.6741739971160888
# Train for this client epoch 2 , loss 0.20112328724861145
# Train for this client epoch 3 , loss 0.03891421800851822
# Train for this client epoch 4 , loss 0.012483802473545075
# Train for this client epoch 5 , loss 0.006097824251651764
# Train for this client epoch 1 , loss 0.6476962890625
# Train for this client epoch 2 , loss 0.18375527902841568
# Train for this client epoch 3 , loss 0.037630927217006685
# Train for this client epoch 4 , loss 0.009621014177799226
# Train for this client epoch 5 , loss 0.005047265660762787
# Train for this client epoch 1 , loss 0.6550063177108765
# Train for this client epoch 2 , loss 0.1927614004135132
# Train for this client epoch 3 , loss 0.037470323061943055
# Train for this client epoch 4 , loss 0.012680657947063446
# Train for this client epoch 5 , loss 0.0063611610651016235
# start aggregation for round 22
# Start Testing
# acc 0.6878206346190385
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564, 0.6861105833174995, 0.685445563366901, 0.687345620368611, 0.6891506745202356, 0.6871556146684401, 0.686205586167585, 0.6884856545696371, 0.6893406802204066, 0.6879156374691241, 0.6876306289188676, 0.6868706061181835, 0.6847805434163025, 0.6883906517195516, 0.68525555766673, 0.687535626068782, 0.6853505605168155, 0.6904807144214327, 0.6878206346190385]
# Round 23 selects [88 13 19 67 60]
# Train for this client epoch 1 , loss 0.4024817785263062
# Train for this client epoch 2 , loss 0.059972510659694674
# Train for this client epoch 3 , loss 0.01459392249584198
# Train for this client epoch 4 , loss 0.004969364154338836
# Train for this client epoch 5 , loss 0.003585679745674133
# Train for this client epoch 1 , loss 0.5171914525985718
# Train for this client epoch 2 , loss 0.10096368302106858
# Train for this client epoch 3 , loss 0.022074281525611878
# Train for this client epoch 4 , loss 0.00875433679819107
# Train for this client epoch 5 , loss 0.005039765620231628
# Train for this client epoch 1 , loss 0.5349876349449157
# Train for this client epoch 2 , loss 0.09694976089000702
# Train for this client epoch 3 , loss 0.0225269664645195
# Train for this client epoch 4 , loss 0.009059282326698304
# Train for this client epoch 5 , loss 0.004590393948554992
# Train for this client epoch 1 , loss 0.6181703290939331
# Train for this client epoch 2 , loss 0.15544670915603637
# Train for this client epoch 3 , loss 0.026739094483852387
# Train for this client epoch 4 , loss 0.011125285851955415
# Train for this client epoch 5 , loss 0.005735384285449982
# Train for this client epoch 1 , loss 0.6544463241577149
# Train for this client epoch 2 , loss 0.1817934012413025
# Train for this client epoch 3 , loss 0.038249343061447144
# Train for this client epoch 4 , loss 0.012601313138008118
# Train for this client epoch 5 , loss 0.005083935868740082
# start aggregation for round 23
# Start Testing
# acc 0.6880106403192096
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564, 0.6861105833174995, 0.685445563366901, 0.687345620368611, 0.6891506745202356, 0.6871556146684401, 0.686205586167585, 0.6884856545696371, 0.6893406802204066, 0.6879156374691241, 0.6876306289188676, 0.6868706061181835, 0.6847805434163025, 0.6883906517195516, 0.68525555766673, 0.687535626068782, 0.6853505605168155, 0.6904807144214327, 0.6878206346190385, 0.6880106403192096]
# Round 24 selects [36 59 97 25 83]
# Train for this client epoch 1 , loss 0.5358629095077515
# Train for this client epoch 2 , loss 0.10141963089704513
# Train for this client epoch 3 , loss 0.02033289942741394
# Train for this client epoch 4 , loss 0.008079657387733459
# Train for this client epoch 5 , loss 0.003960554230213165
# Train for this client epoch 1 , loss 0.6029399149894714
# Train for this client epoch 2 , loss 0.14720521540641784
# Train for this client epoch 3 , loss 0.030381515073776247
# Train for this client epoch 4 , loss 0.009023035335540771
# Train for this client epoch 5 , loss 0.005214238572120666
# Train for this client epoch 1 , loss 0.45757251071929933
# Train for this client epoch 2 , loss 0.06901036990880967
# Train for this client epoch 3 , loss 0.015827109134197236
# Train for this client epoch 4 , loss 0.006889952731132507
# Train for this client epoch 5 , loss 0.0037190458178520203
# Train for this client epoch 1 , loss 0.500959046459198
# Train for this client epoch 2 , loss 0.09034056601524353
# Train for this client epoch 3 , loss 0.022353262174129487
# Train for this client epoch 4 , loss 0.008745832896232606
# Train for this client epoch 5 , loss 0.004129663014411926
# Train for this client epoch 1 , loss 0.38620291776657106
# Train for this client epoch 2 , loss 0.05256623520851135
# Train for this client epoch 3 , loss 0.013399604833126069
# Train for this client epoch 4 , loss 0.0061324671983718874
# Train for this client epoch 5 , loss 0.003643465161323547
# start aggregation for round 24
# Start Testing
# acc 0.6870606118183545
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564, 0.6861105833174995, 0.685445563366901, 0.687345620368611, 0.6891506745202356, 0.6871556146684401, 0.686205586167585, 0.6884856545696371, 0.6893406802204066, 0.6879156374691241, 0.6876306289188676, 0.6868706061181835, 0.6847805434163025, 0.6883906517195516, 0.68525555766673, 0.687535626068782, 0.6853505605168155, 0.6904807144214327, 0.6878206346190385, 0.6880106403192096, 0.6870606118183545]
# Round 25 selects [54 89 27 33 63]
# Train for this client epoch 1 , loss 0.5525401808738708
# Train for this client epoch 2 , loss 0.10783193035125732
# Train for this client epoch 3 , loss 0.021765141594409943
# Train for this client epoch 4 , loss 0.008781547129154205
# Train for this client epoch 5 , loss 0.004482405948638916
# Train for this client epoch 1 , loss 0.6475830062866211
# Train for this client epoch 2 , loss 0.1697152062177658
# Train for this client epoch 3 , loss 0.034366619098186495
# Train for this client epoch 4 , loss 0.00873118313550949
# Train for this client epoch 5 , loss 0.004806992912292481
# Train for this client epoch 1 , loss 0.49091254529953005
# Train for this client epoch 2 , loss 0.07860601489543914
# Train for this client epoch 3 , loss 0.019493008482456206
# Train for this client epoch 4 , loss 0.007870015478134155
# Train for this client epoch 5 , loss 0.0037920619010925294
# Train for this client epoch 1 , loss 0.6593946701049804
# Train for this client epoch 2 , loss 0.18489648487567903
# Train for this client epoch 3 , loss 0.03437510219812393
# Train for this client epoch 4 , loss 0.010998602294921875
# Train for this client epoch 5 , loss 0.00490939770936966
# Train for this client epoch 1 , loss 0.4963696389198303
# Train for this client epoch 2 , loss 0.07890056869983673
# Train for this client epoch 3 , loss 0.021065192580223085
# Train for this client epoch 4 , loss 0.007627362787723541
# Train for this client epoch 5 , loss 0.004195601773262024
# start aggregation for round 25
# Start Testing
# ...
# Round 33 selects [15 31 23 16 71]
# Train for this client epoch 1 , loss 0.37684645929336547
# Train for this client epoch 2 , loss 0.053714967906475064
# Train for this client epoch 3 , loss 0.01465045725107193
# Train for this client epoch 4 , loss 0.006739627814292908
# Train for this client epoch 5 , loss 0.0029934682846069335
# Train for this client epoch 1 , loss 0.34976228995323183
# Train for this client epoch 2 , loss 0.04756509847640991
# Train for this client epoch 3 , loss 0.013332377767562867
# Train for this client epoch 4 , loss 0.005735679578781128
# Train for this client epoch 5 , loss 0.0036259777665138245
# Train for this client epoch 1 , loss 0.4709504107475281
# Train for this client epoch 2 , loss 0.07200769020318985
# Train for this client epoch 3 , loss 0.021817430579662324
# Train for this client epoch 4 , loss 0.006947359490394592
# Train for this client epoch 5 , loss 0.004196526050567627
# Train for this client epoch 1 , loss 0.3942386610984802
# Train for this client epoch 2 , loss 0.04527465236186981
# Train for this client epoch 3 , loss 0.012709276747703552
# Train for this client epoch 4 , loss 0.0046804188370704655
# Train for this client epoch 5 , loss 0.0035129625916481017
# Train for this client epoch 1 , loss 0.32499766006469727
# Train for this client epoch 2 , loss 0.05838983725309372
# Train for this client epoch 3 , loss 0.010947400546073913
# Train for this client epoch 4 , loss 0.00447583121061325
# Train for this client epoch 5 , loss 0.0031736984848976134
# start aggregation for round 33
# Start Testing
# acc 0.6869656089682691
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564, 0.6861105833174995, 0.685445563366901, 0.687345620368611, 0.6891506745202356, 0.6871556146684401, 0.686205586167585, 0.6884856545696371, 0.6893406802204066, 0.6879156374691241, 0.6876306289188676, 0.6868706061181835, 0.6847805434163025, 0.6883906517195516, 0.68525555766673, 0.687535626068782, 0.6853505605168155, 0.6904807144214327, 0.6878206346190385, 0.6880106403192096, 0.6870606118183545, 0.6895306859205776, 0.6893406802204066, 0.6906707201216037, 0.6878206346190385, 0.6869656089682691, 0.6907657229716891, 0.6920007600228006, 0.6905757172715181, 0.6869656089682691]
# Round 34 selects [ 7 76 79 23 35]
# Train for this client epoch 1 , loss 0.5915744564056397
# Train for this client epoch 2 , loss 0.12545746356248855
# Train for this client epoch 3 , loss 0.029201744997501375
# Train for this client epoch 4 , loss 0.008794191539287568
# Train for this client epoch 5 , loss 0.0035989159464836122
# Train for this client epoch 1 , loss 0.4221024129867554
# Train for this client epoch 2 , loss 0.05900863479375839
# Train for this client epoch 3 , loss 0.012412581145763397
# Train for this client epoch 4 , loss 0.005103161382675171
# Train for this client epoch 5 , loss 0.0031115795373916626
# Train for this client epoch 1 , loss 0.3030162257194519
# Train for this client epoch 2 , loss 0.04521842788457871
# Train for this client epoch 3 , loss 0.01328926693201065
# Train for this client epoch 4 , loss 0.006525487160682678
# Train for this client epoch 5 , loss 0.002973039424419403
# Train for this client epoch 1 , loss 0.32111102304458616
# Train for this client epoch 2 , loss 0.05844713604450226
# Train for this client epoch 3 , loss 0.015200410330295563
# Train for this client epoch 4 , loss 0.008163926887512206
# Train for this client epoch 5 , loss 0.00431982752084732
# Train for this client epoch 1 , loss 0.5962375947952271
# Train for this client epoch 2 , loss 0.13381918219327926
# Train for this client epoch 3 , loss 0.02601017155647278
# Train for this client epoch 4 , loss 0.007772244274616241
# Train for this client epoch 5 , loss 0.003473790669441223
# start aggregation for round 34
# Start Testing
# acc 0.6870606118183545
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564, 0.6861105833174995, 0.685445563366901, 0.687345620368611, 0.6891506745202356, 0.6871556146684401, 0.686205586167585, 0.6884856545696371, 0.6893406802204066, 0.6879156374691241, 0.6876306289188676, 0.6868706061181835, 0.6847805434163025, 0.6883906517195516, 0.68525555766673, 0.687535626068782, 0.6853505605168155, 0.6904807144214327, 0.6878206346190385, 0.6880106403192096, 0.6870606118183545, 0.6895306859205776, 0.6893406802204066, 0.6906707201216037, 0.6878206346190385, 0.6869656089682691, 0.6907657229716891, 0.6920007600228006, 0.6905757172715181, 0.6869656089682691, 0.6870606118183545]
# Round 35 selects [79 85  5 98 74]
# Train for this client epoch 1 , loss 0.1519838884115219
# Train for this client epoch 2 , loss 0.04852648723125458
# Train for this client epoch 3 , loss 0.015899688291549682
# Train for this client epoch 4 , loss 0.006811982905864716
# Train for this client epoch 5 , loss 0.004326860690116882
# Train for this client epoch 1 , loss 0.42157259979248046
# Train for this client epoch 2 , loss 0.059160738599300385
# Train for this client epoch 3 , loss 0.01504224625825882
# Train for this client epoch 4 , loss 0.006205539977550506
# Train for this client epoch 5 , loss 0.0027134794116020202
# Train for this client epoch 1 , loss 0.3905981482505798
# Train for this client epoch 2 , loss 0.04590870769023895
# Train for this client epoch 3 , loss 0.012685028755664825
# Train for this client epoch 4 , loss 0.004265695369243622
# Train for this client epoch 5 , loss 0.002779610013961792
# Train for this client epoch 1 , loss 0.6337205432891846
# Train for this client epoch 2 , loss 0.1663559177517891
# Train for this client epoch 3 , loss 0.031224526238441467
# Train for this client epoch 4 , loss 0.01064525043964386
# Train for this client epoch 5 , loss 0.004922560214996338
# Train for this client epoch 1 , loss 0.4984829916000366
# Train for this client epoch 2 , loss 0.08204344429969787
# Train for this client epoch 3 , loss 0.01803259974718094
# Train for this client epoch 4 , loss 0.006858990204334259
# Train for this client epoch 5 , loss 0.003447362184524536
# start aggregation for round 35
# Start Testing
# acc 0.6888656659699791
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564, 0.6861105833174995, 0.685445563366901, 0.687345620368611, 0.6891506745202356, 0.6871556146684401, 0.686205586167585, 0.6884856545696371, 0.6893406802204066, 0.6879156374691241, 0.6876306289188676, 0.6868706061181835, 0.6847805434163025, 0.6883906517195516, 0.68525555766673, 0.687535626068782, 0.6853505605168155, 0.6904807144214327, 0.6878206346190385, 0.6880106403192096, 0.6870606118183545, 0.6895306859205776, 0.6893406802204066, 0.6906707201216037, 0.6878206346190385, 0.6869656089682691, 0.6907657229716891, 0.6920007600228006, 0.6905757172715181, 0.6869656089682691, 0.6870606118183545, 0.6888656659699791]
# Round 36 selects [30  9 91 44 75]
# Train for this client epoch 1 , loss 0.40471866216659547
# Train for this client epoch 2 , loss 0.055329756581783296
# Train for this client epoch 3 , loss 0.01338148330450058
# Train for this client epoch 4 , loss 0.006510648286342621
# Train for this client epoch 5 , loss 0.00353739675283432
# Train for this client epoch 1 , loss 0.48913193578720093
# Train for this client epoch 2 , loss 0.08206029409170151
# Train for this client epoch 3 , loss 0.018522121024131775
# Train for this client epoch 4 , loss 0.008597633469104768
# Train for this client epoch 5 , loss 0.003629937994480133
# Train for this client epoch 1 , loss 0.4925519171714783
# Train for this client epoch 2 , loss 0.07098627597093582
# Train for this client epoch 3 , loss 0.021801469421386718
# Train for this client epoch 4 , loss 0.0075335520982742306
# Train for this client epoch 5 , loss 0.003378216552734375
# Train for this client epoch 1 , loss 0.515609412765503
# Train for this client epoch 2 , loss 0.08267598832845688
# Train for this client epoch 3 , loss 0.017941905307769776
# Train for this client epoch 4 , loss 0.006707884204387665
# Train for this client epoch 5 , loss 0.004166310024261474
# Train for this client epoch 1 , loss 0.5008597936630249
# Train for this client epoch 2 , loss 0.08203599104881287
# Train for this client epoch 3 , loss 0.019929018700122834
# Train for this client epoch 4 , loss 0.008193012082576752
# Train for this client epoch 5 , loss 0.004461861896514893
# start aggregation for round 36
# Start Testing
# acc 0.6925707771233137
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564, 0.6861105833174995, 0.685445563366901, 0.687345620368611, 0.6891506745202356, 0.6871556146684401, 0.686205586167585, 0.6884856545696371, 0.6893406802204066, 0.6879156374691241, 0.6876306289188676, 0.6868706061181835, 0.6847805434163025, 0.6883906517195516, 0.68525555766673, 0.687535626068782, 0.6853505605168155, 0.6904807144214327, 0.6878206346190385, 0.6880106403192096, 0.6870606118183545, 0.6895306859205776, 0.6893406802204066, 0.6906707201216037, 0.6878206346190385, 0.6869656089682691, 0.6907657229716891, 0.6920007600228006, 0.6905757172715181, 0.6869656089682691, 0.6870606118183545, 0.6888656659699791, 0.6925707771233137]
# Round 37 selects [78 39 93  9 85]
# Train for this client epoch 1 , loss 0.39042344160079956
# Train for this client epoch 2 , loss 0.049816456508636475
# Train for this client epoch 3 , loss 0.014951837110519409
# Train for this client epoch 4 , loss 0.005743740689754486
# Train for this client epoch 5 , loss 0.003721723556518555
# Train for this client epoch 1 , loss 0.61014446849823
# Train for this client epoch 2 , loss 0.14805479092597962
# Train for this client epoch 3 , loss 0.028190481102466584
# Train for this client epoch 4 , loss 0.009911488890647888
# Train for this client epoch 5 , loss 0.003947453343868256
# Train for this client epoch 1 , loss 0.5837446265220642
# Train for this client epoch 2 , loss 0.12803168114423752
# Train for this client epoch 3 , loss 0.025447208201885223
# Train for this client epoch 4 , loss 0.007071241164207458
# Train for this client epoch 5 , loss 0.0034685296535491945
# Train for this client epoch 1 , loss 0.3123415991783142
# Train for this client epoch 2 , loss 0.05790046936273575
# Train for this client epoch 3 , loss 0.01609086184501648
# Train for this client epoch 4 , loss 0.005379734551906585
# Train for this client epoch 5 , loss 0.003985611343383789
# Train for this client epoch 1 , loss 0.2763739407539368
# Train for this client epoch 2 , loss 0.04226839329004288
# Train for this client epoch 3 , loss 0.01345585640668869
# Train for this client epoch 4 , loss 0.004908437120914459
# Train for this client epoch 5 , loss 0.0029109457612037657
# start aggregation for round 37
# Start Testing
# acc 0.6925707771233137
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564, 0.6861105833174995, 0.685445563366901, 0.687345620368611, 0.6891506745202356, 0.6871556146684401, 0.686205586167585, 0.6884856545696371, 0.6893406802204066, 0.6879156374691241, 0.6876306289188676, 0.6868706061181835, 0.6847805434163025, 0.6883906517195516, 0.68525555766673, 0.687535626068782, 0.6853505605168155, 0.6904807144214327, 0.6878206346190385, 0.6880106403192096, 0.6870606118183545, 0.6895306859205776, 0.6893406802204066, 0.6906707201216037, 0.6878206346190385, 0.6869656089682691, 0.6907657229716891, 0.6920007600228006, 0.6905757172715181, 0.6869656089682691, 0.6870606118183545, 0.6888656659699791, 0.6925707771233137, 0.6925707771233137]
# Round 38 selects [ 2 22 60 13 74]
# Train for this client epoch 1 , loss 0.6099871669769287
# Train for this client epoch 2 , loss 0.14923952697515488
# Train for this client epoch 3 , loss 0.030871875953674317
# Train for this client epoch 4 , loss 0.010122002792358399
# Train for this client epoch 5 , loss 0.004137679314613342
# Train for this client epoch 1 , loss 0.35161226110458377
# Train for this client epoch 2 , loss 0.042698881483078
# Train for this client epoch 3 , loss 0.010958432281017304
# Train for this client epoch 4 , loss 0.005740527629852295
# Train for this client epoch 5 , loss 0.002653926467895508
# Train for this client epoch 1 , loss 0.5266570209503174
# Train for this client epoch 2 , loss 0.08174093872308731
# Train for this client epoch 3 , loss 0.016174357986450196
# Train for this client epoch 4 , loss 0.005515807855129242
# Train for this client epoch 5 , loss 0.003635319876670837
# Train for this client epoch 1 , loss 0.44622986125946046
# Train for this client epoch 2 , loss 0.06420100539922714
# Train for this client epoch 3 , loss 0.017579529213905334
# Train for this client epoch 4 , loss 0.006959481167793274
# Train for this client epoch 5 , loss 0.0036545243978500365
# Train for this client epoch 1 , loss 0.36717770681381223
# Train for this client epoch 2 , loss 0.048892468643188476
# Train for this client epoch 3 , loss 0.015837246644496917
# Train for this client epoch 4 , loss 0.005584790241718292
# Train for this client epoch 5 , loss 0.0026889134407043457
# start aggregation for round 38
# Start Testing
# acc 0.6889606688200646
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564, 0.6861105833174995, 0.685445563366901, 0.687345620368611, 0.6891506745202356, 0.6871556146684401, 0.686205586167585, 0.6884856545696371, 0.6893406802204066, 0.6879156374691241, 0.6876306289188676, 0.6868706061181835, 0.6847805434163025, 0.6883906517195516, 0.68525555766673, 0.687535626068782, 0.6853505605168155, 0.6904807144214327, 0.6878206346190385, 0.6880106403192096, 0.6870606118183545, 0.6895306859205776, 0.6893406802204066, 0.6906707201216037, 0.6878206346190385, 0.6869656089682691, 0.6907657229716891, 0.6920007600228006, 0.6905757172715181, 0.6869656089682691, 0.6870606118183545, 0.6888656659699791, 0.6925707771233137, 0.6925707771233137, 0.6889606688200646]
# Round 39 selects [60 35 26 36 98]
# Train for this client epoch 1 , loss 0.3490350018978119
# Train for this client epoch 2 , loss 0.05396221808195114
# Train for this client epoch 3 , loss 0.01473332576751709
# Train for this client epoch 4 , loss 0.006239606261253357
# Train for this client epoch 5 , loss 0.0035491915225982665
# Train for this client epoch 1 , loss 0.467882333278656
# Train for this client epoch 2 , loss 0.06267095143795014
# Train for this client epoch 3 , loss 0.011410302233695983
# Train for this client epoch 4 , loss 0.0048974094748497005
# Train for this client epoch 5 , loss 0.002726267111301422
# Train for this client epoch 1 , loss 0.4499689408302307
# Train for this client epoch 2 , loss 0.05711141661405563
# Train for this client epoch 3 , loss 0.012400188672542571
# Train for this client epoch 4 , loss 0.004492033922672271
# Train for this client epoch 5 , loss 0.0025854316234588622
# Train for this client epoch 1 , loss 0.4717466018676758
# Train for this client epoch 2 , loss 0.05872495294809341
# Train for this client epoch 3 , loss 0.015302093291282653
# Train for this client epoch 4 , loss 0.00528735761642456
# Train for this client epoch 5 , loss 0.0028228941559791565
# Train for this client epoch 1 , loss 0.49380615711212156
# Train for this client epoch 2 , loss 0.07213613569736481
# Train for this client epoch 3 , loss 0.016937583017349243
# Train for this client epoch 4 , loss 0.007042274689674378
# Train for this client epoch 5 , loss 0.0036760703802108763
# start aggregation for round 39
# Start Testing
# acc 0.6847805434163025
# [0.6312939388181645, 0.6593197795933878, 0.6708151244537336, 0.6770853125593768, 0.6798403952118564, 0.6861105833174995, 0.685445563366901, 0.687345620368611, 0.6891506745202356, 0.6871556146684401, 0.686205586167585, 0.6884856545696371, 0.6893406802204066, 0.6879156374691241, 0.6876306289188676, 0.6868706061181835, 0.6847805434163025, 0.6883906517195516, 0.68525555766673, 0.687535626068782, 0.6853505605168155, 0.6904807144214327, 0.6878206346190385, 0.6880106403192096, 0.6870606118183545, 0.6895306859205776, 0.6893406802204066, 0.6906707201216037, 0.6878206346190385, 0.6869656089682691, 0.6907657229716891, 0.6920007600228006, 0.6905757172715181, 0.6869656089682691, 0.6870606118183545, 0.6888656659699791, 0.6925707771233137, 0.6925707771233137, 0.6889606688200646, 0.6847805434163025]
